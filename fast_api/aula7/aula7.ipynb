# %% [markdown]
# # Aula 7: Revisão geral e sugestões de projeto.

# %% [markdown]
# ## Usando um projeto existente:
#
# Caso você já tenha um projeto que está em algum repositório (ex:github) vc pode usar os seguintes comando para executá-lo na sua máquina:
#
# 1. Instalando ambiente virtual:
# ```bash
# python -m venv .venv
# ```
#
# 2. Executando o ambiente virtual:
# ```bash
# .venv/Scripts/activate
# ```
#
# 3. Instalando dependências:
#
# - Caso vc tenha um arquivo _"requirements.txt"_ no seu projeto você pode executar o seguinte comando que irá instalar todas as dependencias necessárias:
#
# ```bash
# pip install -r requirements.txt
# ```
# - Do contrário vc terá que instalar as dependências na medida que for necessário:
#
# ```bash
# pip install biblioteca1 framework1 biblioteca2
# ```
#
# 4. Executando o projeto:
#
# ```bash
# uvicorn main:app --reload
# ```
#
# __Obs.:__
# - _main_ é o nome do arquivo em que você instancia a classe do Fast-API
# - app é o nome da variável que está com a instancia da classe Fast-API
#
# ```python
# app = FastAPI() # Intanciei a classe do fastapi
# ```

# %% [markdown]
# ## 1. API de Sorteios e Rifas 🎟️
# Descrição: Criar uma API para gerenciar sorteios, onde os usuários podem cadastrar participantes e sortear um vencedor.
#
# ### Funcionalidades:
#
# - Criar um novo sorteio (POST /sorteios)
# - Adicionar participantes a um sorteio (POST /sorteios/{id}/participantes)
# - Listar sorteios ativos (GET /sorteios)
# - Sortear um vencedor (POST /sorteios/{id}/sortear)
# - Encerrar um sorteio (PUT /sorteios/{id}/encerrar)
#
# ### Tecnologias:
#
# - FastAPI
# - MySQL para armazenar sorteios e participantes
# - JWT  para proteger a criação de sorteios
#
# ## Extra:
#
# - Criar um front-end com React/Vue para exibir os sorteios
# - Permitir sorteios com prêmios personalizados
#
#
# ## 2. API de Gerenciamento de Biblioteca Digital 📚
# Descrição: Criar uma API para gerenciar livros e usuários que podem fazer empréstimos.
#
# ### Funcionalidades:
#
# - Adicionar livros à biblioteca (POST /livros)
# - Listar todos os livros disponíveis (GET /livros)
# - Registrar usuários (POST /usuarios)
# - Realizar empréstimos de livros (POST /emprestimos)
# - Consultar histórico de empréstimos (GET /historico)
#
# ### Tecnologias:
#
# - FastAPI
# - MySQL para armazenar livros e usuários
# - JWT para autenticação dos usuários
#
# ### Extra:
#
# - Implementar um sistema de multas para atrasos nos empréstimos
# - Criar um painel administrativo para gerenciar a biblioteca
#
#
#
# ## 3. API de Avaliação de Filmes e Séries 🎬
# Descrição: Criar uma API para os usuários avaliarem filmes e séries, deixando comentários e notas.
#
# ### Funcionalidades:
#
# - Cadastrar filmes e séries (POST /midia)
# - Listar filmes e séries (GET /midia)
# - Adicionar avaliações (POST /avaliacoes)
# - Listar avaliações de um filme/série específico (GET /avaliacoes/{midia_id})
# - Filtrar por gênero ou nota mínima (GET /midia?genero=Ação&nota_minima=8)
#
# ### Tecnologias:
#
# - FastAPI
# - MySQL
# - JWT para autenticação
#
# ### Extra:
#
# - Criar um ranking de filmes/séries mais bem avaliados
# - Permitir que usuários favoritem filmes/séries
#
#
# ## 4. API de Sorteio de Amigo Secreto 🎁
# Descrição: Criar uma API que permite organizar um amigo secreto e notificar os participantes sobre seus sorteios.
#
# ### Funcionalidades:
#
# - Criar um novo sorteio (POST /sorteio)
# - Adicionar participantes (POST /sorteio/{id}/participantes)
# - Realizar o sorteio e enviar os resultados (POST /sorteio/{id}/sortear)
# - Consultar o sorteio (GET /sorteio/{id})
#
# ### Tecnologias:
#
# - FastAPI
# - MySQL para armazenar sorteios
# - Biblioteca SMTP para enviar e-mails com os resultados
#
# Extra:
#
# - Criar um sistema de mensagens anônimas entre os participantes
# - Gerar um link único para cada sorteio
